# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_csv('Q:/4. Learning/3nd year students/1. Data business analytics/Report Data Business Analytics/time-series-forecasting/Dataset/FPT.csv')
df1=df.reset_index()['Price']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

# %%
# 8. Define LSTM Model
# Define the model
model = Sequential()

# Add a 1D convolutional layer
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(100,1)))

# Add a max pooling layer
model.add(MaxPooling1D(pool_size=2))

# Add another 1D convolutional layer
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))

# Add a bidirectional LSTM layer
model.add(Bidirectional(LSTM(100, activation='relu')))

# Add a dense output layer
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 3s 82ms/step - loss: 0.1057 - val_loss: 0.0060
# Epoch 2/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0155 - val_loss: 0.0159
# Epoch 3/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0087 - val_loss: 0.0444
# Epoch 4/100
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0042 - val_loss: 0.0088
# Epoch 5/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0027 - val_loss: 0.0193
# Epoch 6/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0022 - val_loss: 0.0247
# Epoch 7/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0019 - val_loss: 0.0149
# Epoch 8/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0016 - val_loss: 0.0110
# Epoch 9/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0013 - val_loss: 0.0154
# Epoch 10/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0013 - val_loss: 0.0067
# Epoch 11/100
# 11/11 [==============================] - 1s 51ms/step - loss: 9.0559e-04 - val_loss: 0.0042
# Epoch 12/100
# 11/11 [==============================] - 1s 50ms/step - loss: 7.2560e-04 - val_loss: 0.0027
# Epoch 13/100
# 11/11 [==============================] - 1s 51ms/step - loss: 6.3189e-04 - val_loss: 0.0015
# Epoch 14/100
# 11/11 [==============================] - 1s 51ms/step - loss: 5.6910e-04 - val_loss: 0.0017
# Epoch 15/100
# 11/11 [==============================] - 1s 52ms/step - loss: 5.9232e-04 - val_loss: 0.0017
# Epoch 16/100
# 11/11 [==============================] - 1s 54ms/step - loss: 5.4414e-04 - val_loss: 0.0016
# Epoch 17/100
# 11/11 [==============================] - 1s 52ms/step - loss: 5.2400e-04 - val_loss: 0.0015
# Epoch 18/100
# 11/11 [==============================] - 1s 51ms/step - loss: 5.0350e-04 - val_loss: 0.0016
# Epoch 19/100
# 11/11 [==============================] - 1s 51ms/step - loss: 4.9101e-04 - val_loss: 0.0017
# Epoch 20/100
# 11/11 [==============================] - 1s 51ms/step - loss: 4.8742e-04 - val_loss: 0.0015
# Epoch 21/100
# 11/11 [==============================] - 1s 52ms/step - loss: 5.0020e-04 - val_loss: 0.0016
# Epoch 22/100
# 11/11 [==============================] - 1s 53ms/step - loss: 4.6656e-04 - val_loss: 0.0015
# Epoch 23/100
# 11/11 [==============================] - 1s 51ms/step - loss: 4.8525e-04 - val_loss: 0.0018
# Epoch 24/100
# 11/11 [==============================] - 1s 52ms/step - loss: 4.8845e-04 - val_loss: 0.0019
# Epoch 25/100
# 11/11 [==============================] - 1s 52ms/step - loss: 5.9204e-04 - val_loss: 0.0015
# Epoch 26/100
# 11/11 [==============================] - 1s 53ms/step - loss: 5.3485e-04 - val_loss: 0.0023
# Epoch 27/100
# 11/11 [==============================] - 1s 58ms/step - loss: 5.3985e-04 - val_loss: 0.0017
# Epoch 28/100
# 11/11 [==============================] - 1s 53ms/step - loss: 5.2761e-04 - val_loss: 0.0016
# Epoch 29/100
# 11/11 [==============================] - 1s 55ms/step - loss: 4.8866e-04 - val_loss: 0.0016
# Epoch 30/100
# 11/11 [==============================] - 1s 54ms/step - loss: 4.3719e-04 - val_loss: 0.0015
# Epoch 31/100
# 11/11 [==============================] - 1s 60ms/step - loss: 4.4442e-04 - val_loss: 0.0015
# Epoch 32/100
# 11/11 [==============================] - 1s 53ms/step - loss: 4.1661e-04 - val_loss: 0.0015
# Epoch 33/100
# 11/11 [==============================] - 1s 54ms/step - loss: 4.2841e-04 - val_loss: 0.0019
# Epoch 34/100
# 11/11 [==============================] - 1s 52ms/step - loss: 4.4250e-04 - val_loss: 0.0015
# Epoch 35/100
# 11/11 [==============================] - 1s 57ms/step - loss: 4.1826e-04 - val_loss: 0.0015
# Epoch 36/100
# 11/11 [==============================] - 1s 51ms/step - loss: 4.2675e-04 - val_loss: 0.0017
# Epoch 37/100
# 11/11 [==============================] - 1s 52ms/step - loss: 4.1883e-04 - val_loss: 0.0014
# Epoch 38/100
# 11/11 [==============================] - 1s 52ms/step - loss: 4.0107e-04 - val_loss: 0.0014
# Epoch 39/100
# 11/11 [==============================] - 1s 51ms/step - loss: 4.0720e-04 - val_loss: 0.0020
# Epoch 40/100
# 11/11 [==============================] - 1s 49ms/step - loss: 4.0650e-04 - val_loss: 0.0014
# Epoch 41/100
# 11/11 [==============================] - 1s 57ms/step - loss: 4.0259e-04 - val_loss: 0.0014
# Epoch 42/100
# 11/11 [==============================] - 1s 52ms/step - loss: 4.2580e-04 - val_loss: 0.0014
# Epoch 43/100
# 11/11 [==============================] - 1s 55ms/step - loss: 4.1522e-04 - val_loss: 0.0016
# Epoch 44/100
# 11/11 [==============================] - 1s 51ms/step - loss: 4.1943e-04 - val_loss: 0.0014
# Epoch 45/100
# 11/11 [==============================] - 1s 50ms/step - loss: 3.8348e-04 - val_loss: 0.0016
# Epoch 46/100
# 11/11 [==============================] - 1s 49ms/step - loss: 3.8968e-04 - val_loss: 0.0024
# Epoch 47/100
# 11/11 [==============================] - 1s 58ms/step - loss: 4.2213e-04 - val_loss: 0.0014
# Epoch 48/100
# 11/11 [==============================] - 1s 56ms/step - loss: 3.7193e-04 - val_loss: 0.0017
# Epoch 49/100
# 11/11 [==============================] - 1s 52ms/step - loss: 3.8499e-04 - val_loss: 0.0014
# Epoch 50/100
# 11/11 [==============================] - 1s 50ms/step - loss: 3.8913e-04 - val_loss: 0.0014
# Epoch 51/100
# 11/11 [==============================] - 1s 50ms/step - loss: 3.9257e-04 - val_loss: 0.0013
# Epoch 52/100
# 11/11 [==============================] - 1s 60ms/step - loss: 3.7013e-04 - val_loss: 0.0013
# Epoch 53/100
# 11/11 [==============================] - 1s 63ms/step - loss: 3.5960e-04 - val_loss: 0.0015
# Epoch 54/100
# 11/11 [==============================] - 1s 74ms/step - loss: 3.7911e-04 - val_loss: 0.0013
# Epoch 55/100
# 11/11 [==============================] - 1s 80ms/step - loss: 4.0508e-04 - val_loss: 0.0017
# Epoch 56/100
# 11/11 [==============================] - 1s 66ms/step - loss: 3.9824e-04 - val_loss: 0.0021
# Epoch 57/100
# 11/11 [==============================] - 1s 74ms/step - loss: 4.0314e-04 - val_loss: 0.0014
# Epoch 58/100
# 11/11 [==============================] - 1s 70ms/step - loss: 3.7312e-04 - val_loss: 0.0014
# Epoch 59/100
# 11/11 [==============================] - 1s 60ms/step - loss: 3.5584e-04 - val_loss: 0.0015
# Epoch 60/100
# 11/11 [==============================] - 1s 62ms/step - loss: 3.4258e-04 - val_loss: 0.0014
# Epoch 61/100
# 11/11 [==============================] - 1s 65ms/step - loss: 3.6180e-04 - val_loss: 0.0015
# Epoch 62/100
# 11/11 [==============================] - 1s 68ms/step - loss: 3.3779e-04 - val_loss: 0.0013
# Epoch 63/100
# 11/11 [==============================] - 1s 61ms/step - loss: 3.3610e-04 - val_loss: 0.0014
# Epoch 64/100
# 11/11 [==============================] - 1s 66ms/step - loss: 3.3711e-04 - val_loss: 0.0015
# Epoch 65/100
# 11/11 [==============================] - 1s 62ms/step - loss: 3.3128e-04 - val_loss: 0.0013
# Epoch 66/100
# 11/11 [==============================] - 1s 66ms/step - loss: 3.4747e-04 - val_loss: 0.0014
# Epoch 67/100
# 11/11 [==============================] - 1s 63ms/step - loss: 3.2729e-04 - val_loss: 0.0013
# Epoch 68/100
# 11/11 [==============================] - 1s 63ms/step - loss: 3.3908e-04 - val_loss: 0.0014
# Epoch 69/100
# 11/11 [==============================] - 1s 65ms/step - loss: 3.4818e-04 - val_loss: 0.0018
# Epoch 70/100
# 11/11 [==============================] - 1s 68ms/step - loss: 3.4064e-04 - val_loss: 0.0015
# Epoch 71/100
# 11/11 [==============================] - 1s 69ms/step - loss: 3.1813e-04 - val_loss: 0.0013
# Epoch 72/100
# 11/11 [==============================] - 1s 65ms/step - loss: 3.1429e-04 - val_loss: 0.0013
# Epoch 73/100
# 11/11 [==============================] - 1s 66ms/step - loss: 3.0531e-04 - val_loss: 0.0012
# Epoch 74/100
# 11/11 [==============================] - 1s 62ms/step - loss: 3.0165e-04 - val_loss: 0.0019
# Epoch 75/100
# 11/11 [==============================] - 1s 65ms/step - loss: 3.0559e-04 - val_loss: 0.0014
# Epoch 76/100
# 11/11 [==============================] - 1s 61ms/step - loss: 2.9874e-04 - val_loss: 0.0013
# Epoch 77/100
# 11/11 [==============================] - 1s 59ms/step - loss: 3.1917e-04 - val_loss: 0.0025
# Epoch 78/100
# 11/11 [==============================] - 1s 67ms/step - loss: 3.5509e-04 - val_loss: 0.0013
# Epoch 79/100
# 11/11 [==============================] - 1s 61ms/step - loss: 2.9759e-04 - val_loss: 0.0017
# Epoch 80/100
# 11/11 [==============================] - 1s 58ms/step - loss: 3.2091e-04 - val_loss: 0.0012
# Epoch 81/100
# 11/11 [==============================] - 1s 57ms/step - loss: 3.0332e-04 - val_loss: 0.0017
# Epoch 82/100
# 11/11 [==============================] - 1s 61ms/step - loss: 3.0346e-04 - val_loss: 0.0012
# Epoch 83/100
# 11/11 [==============================] - 1s 58ms/step - loss: 3.0024e-04 - val_loss: 0.0012
# Epoch 84/100
# 11/11 [==============================] - 1s 58ms/step - loss: 2.9427e-04 - val_loss: 0.0013
# Epoch 85/100
# 11/11 [==============================] - 1s 63ms/step - loss: 2.8721e-04 - val_loss: 0.0012
# Epoch 86/100
# 11/11 [==============================] - 1s 63ms/step - loss: 2.8600e-04 - val_loss: 0.0013
# Epoch 87/100
# 11/11 [==============================] - 1s 71ms/step - loss: 2.7885e-04 - val_loss: 0.0013
# Epoch 88/100
# 11/11 [==============================] - 1s 63ms/step - loss: 2.7064e-04 - val_loss: 0.0012
# Epoch 89/100
# 11/11 [==============================] - 1s 64ms/step - loss: 2.6666e-04 - val_loss: 0.0015
# Epoch 90/100
# 11/11 [==============================] - 1s 69ms/step - loss: 3.0925e-04 - val_loss: 0.0017
# Epoch 91/100
# 11/11 [==============================] - 1s 61ms/step - loss: 3.4154e-04 - val_loss: 0.0012
# Epoch 92/100
# 11/11 [==============================] - 1s 60ms/step - loss: 2.7160e-04 - val_loss: 0.0012
# Epoch 93/100
# 11/11 [==============================] - 1s 62ms/step - loss: 2.7008e-04 - val_loss: 0.0012
# Epoch 94/100
# 11/11 [==============================] - 1s 65ms/step - loss: 2.8191e-04 - val_loss: 0.0015
# Epoch 95/100
# 11/11 [==============================] - 1s 62ms/step - loss: 2.6963e-04 - val_loss: 0.0016
# Epoch 96/100
# 11/11 [==============================] - 1s 63ms/step - loss: 2.6995e-04 - val_loss: 0.0013
# Epoch 97/100
# 11/11 [==============================] - 1s 62ms/step - loss: 2.6570e-04 - val_loss: 0.0012
# Epoch 98/100
# 11/11 [==============================] - 1s 64ms/step - loss: 2.8361e-04 - val_loss: 0.0015
# Epoch 99/100
# 11/11 [==============================] - 1s 67ms/step - loss: 2.5647e-04 - val_loss: 0.0014
# Epoch 100/100
# 11/11 [==============================] - 1s 63ms/step - loss: 2.5321e-04 - val_loss: 0.0016

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)
# Out:
# 21/21 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
valid_rmse = np.sqrt(np.mean((y_pred_val - yval)**2))
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
print('Validation RMSE:', valid_rmse)
print('Testing RMSE:', test_rmse)
# Out:
# Validation RMSE: 77667.45828919167
# Testing RMSE: 79506.68848355809

# %%
# 13. Dự báo 30 ngày tiếp theo
x_input=val_data[60:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<7):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, 49,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# [0.7410334]
# 50
# [0.7410334]
# 51
# [0.7410334]
# 52
# [0.7410334]
# 53
# [0.7410334]
# 54
# [0.7410334]
# 55
# [0.7410334]
# 56

# %%
# 14.Vẽ hình
plt.figure(figsize=(16,9))
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred))
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
plt.plot(val_data_index,scaler.inverse_transform(val_data))
val_data_index = pd.RangeIndex(start=train_size+test_size+101, stop=train_size+test_size+val_size, step=1)
plt.plot(val_data_index,y_pred_val)
prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+6, step=1)
plt.plot(prediect_data_index,scaler.inverse_transform(lst_output))
plt.legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])
plt.show()

# %%
print(scaler.inverse_transform(lst_output))
# Out:
# [[76684.47580218]
#  [76684.47580218]
#  [76684.47580218]
#  [76684.47580218]
#  [76684.47580218]
#  [76684.47580218]
#  [76684.47580218]]
